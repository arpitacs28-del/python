# %% [markdown]
# CONDITION STATEMENTS
# -IF : Multiple conditions
# -ELIF : Multiple conditions
# -ELSE IF : Single conditions
# -NESTED IF : Multiple conditions but with different concept

# %%
marks =85
if marks>=90:
        print("A+")
if marks>=75:
        print("A")
if marks>=60:
        print("B")
if marks<60:
        print("Fail")
# Out:
# A
# B

# %%
marks =85
if marks>=90:
    print("A+")
elif marks>=75:
        print("A")
elif marks>=60:
            print("B")
elif marks<60:
                print("Fail")
else:
    print("Invalid marks")
# Out:
# A

# %%
age=90
if age>=18:
    print("You are eligible to vote")
else:
    printf("Youare not eligible to vote")
# Out:
# You are eligible to vote

# %%
number = -6
if number>=0:
    print("positive number")
if number<=0:
   print("negative number")
# Out:
# negative number

# %%
number = 8
if number%2==0:
    print("even number")
else:
   print("odd number")
# Out:
# even number

# %%
vowels='a,e,i,o,u'
char='a'
if char in vowels:
  print("character is vowel ")
else:
  print("char is not in vowel")
# Out:
# char is not in vowel

# %%
side1=input("enter side1:")
side2=input("enter side2:")
if side1==side2:
    print("both sides are equal")
else:
     print("both sides are not equal")
# Out:
# both sides are not equal

# %%
side1=12
side2=12
side3=13
if side1==side2==side3:
    print("it is an equilateral triangle")
if side1==side2!=side3:
    print("it is an iscoceles triangle")
# Out:
# it is an iscoceles triangle

# %%
radius = float(input("enter the radius of the circle"))
if radius<=0:
    print("Error: radius must be a positive number greater than zero.")
else:
    area = 3.14159*radius*radius
    print("the area of circle is:",area)
# Out:
# the area of circle is: 113.09723999999999

# %%
username = input("Enter your username:")
email = input("Enter you email:")
password = input("Enter your password:")
c_pass = input("Enter your c_pass:")
if len(username)>=8 and len(username)<=15:
    if'@' in email and '.' in email:
        if len(password)>=8 and len(password)<=15:
            if password==c_pass:
                printf("registration successful")
            else:
                printf("password does not match")
        else:
            printf("password must be between 8 and 15 characters")
    else:
        printf("invalid email format")
else:
    printf("username must be between 8 and 15 characters")

# %%
marks = input("enter your marks:")
age = input("enter you age:")
if marks>=60:
    if age>=18:
        print("admission successful")
    else:
        print("your age is not eligible")
else:
    print("your marks are not in the eligibility criteria")
